# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#!pip install numpy
#!pip install matplotlib

# %%
# tipado dinámico

# %%
a = 0
b = 1.
c = 'alejandro'

# %%
type(c)
# Out:
# str

# %% [markdown]
# $$ y = 2x+1 $$

# %%
# funcion
# Python es identado
def Funcion1(x): # operador de ambito
    return 2*x**2 + 1

# %%
# Evaluando en un punto
Funcion1(1)
# Out:
# 3

# %%
x = np.linspace(-10,10,2001) # min, max, numero de puntos
x
# Out:
# array([-10.  ,  -9.99,  -9.98, ...,   9.98,   9.99,  10.  ])

# %%
y = Funcion1(x)

# %%
y
# Out:
# array([201.    , 200.6002, 200.2008, ..., 200.2008, 200.6002, 201.    ])

# %%
# Loops
y1 = np.zeros(len(x))
print(y)
for i in range(len(x)):
    #print(i)
    y1[i] = Funcion1(x[i])
    #print(y1[i])
# Out:
# [201.     200.6002 200.2008 ... 200.2008 200.6002 201.    ]

# %%
y1
# Out:
# array([201.    , 200.6002, 200.2008, ..., 200.2008, 200.6002, 201.    ])

# %%
plt.plot(x,y,lw=2,ls='--',label='f(x)')
plt.plot(x,y1,lw=2,color='r',ls='--',label='f(x) 2')
plt.legend(loc=1,fontsize=15)
plt.xlabel(r'$t[s]$',fontsize=15)
plt.ylabel(r'$x[m]$',fontsize=15)
# Out:
# Text(0, 0.5, '$x[m]$')

# %%
def Exponencial(x,lambda_):
    return lambda_*np.exp( - lambda_*x )

# %%
x = np.linspace(0,2,50)
y = Exponencial(x,lambda_=5)

# %%
for i in range(1,11):
    #print(i)
    y = Exponencial(x,lambda_=i)
    plt.plot(x,y,lw=2,ls='--',label='exp(x)')

# %%
def Funcion3(x):
    
    if x < 0:
        print('El numero es negativo')
    else:
        print('El numero es positivo')

# %%
Funcion3(-432656)
# Out:
# El numero es negativo

# %%
def Factorial(n):
    
    fact = 1
    i = 1
    
    if n == 0:
        return fact
    else:
        
        while i <= n:
            print(i)
            fact *= i
            i += 1
            
        return fact

# %%
Factorial(5)
# Out:
# 1
# 2
# 3
# 4
# 5
# 120
